# %%
import pandas as pd
df = pd.read_csv('MarketingReport_3.csv', sep="\t")
df.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         account businessUnit  periodCode reportGranularity salesChannel  \
# 0  audiopartner     kytaryro    20190101             Daily       online
# 1  audiopartner     kytaryro    20190101             Daily       online
# 2  audiopartner     kytaryro    20190101             Daily       online
# 3  audiopartner     kytaryro    20190101             Daily       online
# 4  audiopartner     kytaryro    20190101             Daily       online
#
#     platformId platformCode             channelId       channelCode tagCodes  \
# 0   280_unpaid       unpaid            280_direct            direct      NaN
# 1  280_adwords      AdWords  280_googleadsdsother  googleadsdsother      NaN
# ...

# %%
df['adCampaign'].head(30)
# Out:
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                     -
# 4                                             (not set)
# 5                                                   all
# 6                                                   all
# 7                                                   all
# 8                                                 Brand
# 9                  BW (Product) - Dechy a příslušenství
# 10                 BW (Product) - Dechy a příslušenství
# 11                 BW (Product) - Dechy a příslušenství
# 12                 BW (Product) - Dechy a příslušenství
# 13                 BW (Product) - Dechy a příslušenství
# 14     BW (Product) - Dechy a příslušenství (non-brand)
# 15     BW (Product) - Dechy a příslušenství (non-brand)
# 16    BW (Product) - Klavesy a prislusenstvi (non-br...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 552145 entries, 0 to 552144
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   account                  552145 non-null  object
#  1   businessUnit             552145 non-null  object
#  2   periodCode               552145 non-null  int64
#  3   reportGranularity        552145 non-null  object
#  4   salesChannel             552145 non-null  object
#  5   platformId               552145 non-null  object
#  6   platformCode             552145 non-null  object
#  7   channelId                552145 non-null  object
#  8   channelCode              552145 non-null  object
#  9   tagCodes                 29731 non-null   object
#  10  site                     552145 non-null  object
#  11  adSource                 552145 non-null  object
#  12  adMedium                 552145 non-null  object
# ...

# %% [markdown]
# ### Data filtering
#
# https://stackoverflow.com/questions/20618804/how-to-smooth-a-curve-in-the-right-way

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Convolutions filtering
x = np.linspace(0,2*np.pi,100)
y = np.sin(x) + np.random.random(100) * 0.8



def smooth(y, box_pts):
    box = np.ones(box_pts)/box_pts             # weght's coeffinients 
    y_smooth = np.convolve(y, box, mode='same')
    return y_smooth

plt.plot(x, y,'o')
plt.plot(x, smooth(y,3), 'r-', lw=2)
plt.plot(x, smooth(y,19), 'g-', lw=2)

# %%
# np.cumsum  could be better in terms of speed

# %%
df['median']= df['b'].rolling(window).median()
df['std'] = df['b'].rolling(window).std()

# %%
df = pd.DataFrame(y, columns = ['y'], index = x )
df
# Out:
#                  y
# 0.000000  0.788458
# 0.063467  0.165703
# 0.126933  0.131507
# 0.190400  0.792458
# 0.253866  0.875493
# ...            ...
# 6.029319  0.025762
# 6.092786 -0.181241
# 6.156252  0.503975
# 6.219719  0.131148
# 6.283185  0.303864
#
# [100 rows x 1 columns]

# %%
window = 3
df['median']= df['y'].rolling(window).median()
df['std'] = df['y'].rolling(window).std()
df.plot()
# Out:
# <AxesSubplot:>
